# %% [markdown]
# ## GeoPandas Demo: Get Counties
# After the quick introduction, this script explores using GeoPandas in a difference context. Specficially, it looks at the mashup of `GeoPandas` and the `Requests` package to enable us to access features served in an ArcGIS Map Service as a GeoPandas dataframe.

# %%
import requests
import pandas as pd
import geopandas as gpd

# %matplotlib inline

# %% [markdown]
# ### Fetching the data
# * Build the request
# * Send the request, receive the response

# %%
#Build the request and parameters to fetch county features
#  from the NOAA ArcGIS map server end point
stateFIPS = '37' #This is NC

url = 'https://nowcoast.noaa.gov/arcgis/rest/services/nowcoast/mapoverlays_political/MapServer/find'
params = {'searchText':stateFIPS,
          'contains':'true',
          'searchFields':'STATEFP',
          'sr':'',
          'layers':'2',
          'layerDefs':'',
          'returnGeometry':'true',
          'maxAllowableOffset':'',
          'geometryPrecision':'',
          'dynamicLayers':'',
          'returnZ':'false',
          'returnM':'false',
          'gdbVersion':'',
          'returnUnformattedValues':'false',
          'returnFieldName':'false',
          'datumTransformations':'',
          'layerParameterValues':'',
          'mapRangeValues':'',
          'layerRangeValues':'',
          'f':'json'}

# %%
#Fetch the data
response = requests.get(url,params)

# %% [markdown]
# ### Examining the response
# * Convert the response to a JSON object
# * Examine its structure
# * Extract the `attributes` and `geometry` elements.

# %%
#Convert to a JSON object (i.e. a dictionary)
respons_js = response.json()

# %%
#The 'results' object contains a record for each county returned
results = respons_js['results']
len(results)
# Out:
# 100

# %%
#Within each item in the results object are the following items
results[0].keys()
# Out:
# dict_keys(['layerId', 'layerName', 'displayFieldName', 'foundFieldName', 'value', 'attributes', 'geometryType', 'geometry'])

# %%
#The 'attributes' item contains the feature attributes
results[0]['attributes']
# Out:
# {'FID': '159',
#  'Shape': 'Polygon',
#  'STATEFP': '37',
#  'COUNTYFP': '015',
#  'COUNTYNS': '01026334',
#  'GEOID': '37015',
#  'NAME': 'Bertie',
#  'LSAD': '06',
#  'ALAND': '1811097673',
#  'AWATER': '108727758',
#  'AFFGEOID': '0500000US37015'}

# %%
#And the geometry object contains the shape
results[0]['geometry']
# Out:
# {'rings': [[[-8608078.87744889, 4310879.947869732],
#    [-8607855.681813259, 4311157.199401064],
#    [-8607283.054183457, 4311298.513661726],
#    [-8607034.255056638, 4311564.619169095],
#    [-8606785.344632704, 4312363.801388674],
#    [-8606679.591093063, 4312576.761309607],
#    [-8606465.968933858, 4312789.725423373],
#    [-8604441.846024798, 4313053.388036737],
#    [-8604014.71301244, 4313159.460997633],
#    [-8603356.146725837, 4313691.63226638],
#    [-8603036.771017909, 4313902.138504786],
#    [-8602309.965851361, 4314167.756942879],
#    [-8601812.256260224, 4314273.703053501],
#    [-8601279.258377463, 4314326.194305609],
#    [-8599856.483525068, 4314199.857638092],
#    [-8599358.662606183, 4314110.444661026],
#    [-8599111.978533875, 4313985.6259121755],
#    [-8598792.602814078, 4313914.124437068],
#    [-8598526.103873806, 4313967.027238429],
#    [-8593372.8998097, 4299148.917143934],
#    [-8593451.268771866, 4299548.869044962],
#    [-8593514.052987425, 4299633.896837061],
#    [-8594263.344712926, 4299724.9790981095],
#    [-8594623.908649942, 4299630.457141721],
#    [-8594868.366316894, 4299400.415904923],
#    [-8595197.649469657, 4299359.416232253],
#    [-8595282.474952232, 4299470.858615952],
#    [-8595339.693193154, 4299594.409659441],
#    [-8595306.742626278, 4299893.386998177],
#    [-8595112.490068484, 4300206.131893999],
#    [-8594815.489592599, 4300598.830068129],
#    [-8594539.08324613, 4301406.561586345],
#    [-8594614.4465726, 4301601.82972397],
#    [-8595244.849062685, 4302102.4697821],
#    [-8595565.226672705, 4302522.072946793],
#    [-8595850.427302685, 4302697.680788046],
#    [-8596273.775456049, 4302707.039262238],
#    [-8596753.673925651, 4302659.558740865],
#    [-8597208.414187377, 4302725.480980768],
#    [-8597421.702401834, 4302841.912495707],
#    [-8597864.086208027, 4303188.324295406],
#    [-8598764.661184233, 4303672.934007043],
#    [-8599789.691385042, 4304057.912041336],
#    [-8600369.888762234, 4304386.331003743],
#    [-8601085.339367311, 4304839.196602817],
#    [-8601805.576703655, 4305093.718111063],
#    [-8602183.061220672, 4305291.943442741],
#    [-8602614.201757384, 4305698.45438031],
#    [-8603095.547396092, 4306016.46034889],
#    [-8603960.834090346, 4306677.832511596],
#    [-8605118.779814038, 4307306.889384316],
#    [-8605637.974087339, 4307532.967763023],
#    [-8605873.971486459, 4307687.31509473],
#    [-8606917.592051525, 4308158.494217516],
#    [-8607458.493638141, 4308526.832328195],
#    [-8607596.641180772, 4308820.134818348],
#    [-8608063.960604025, 4310200.966413718],
#    [-8608078.87744889, 4310879.947869732]]],
#  'spatialReference': {'wkid': 102100, 'latestWkid': 3857}}

# %% [markdown]
# ### Convert the elements to dataFrames
# * Creating a dataFrame from the Results object
# * "Exploding" the values in the `attributes` and `geometry` columns
# * Concatenating dataFrames lengthwise (adding columns)

# %%
#Create a dataFrame from the results, 
#  keeping just the attributes and geometry objects
df = pd.DataFrame(results,columns=('attributes','geometry'))
df.head()
# Out:
#                                           attributes  \
# 0  {'FID': '159', 'Shape': 'Polygon', 'STATEFP': ...
# 1  {'FID': '160', 'Shape': 'Polygon', 'STATEFP': ...
# 2  {'FID': '161', 'Shape': 'Polygon', 'STATEFP': ...
# 3  {'FID': '162', 'Shape': 'Polygon', 'STATEFP': ...
# 4  {'FID': '163', 'Shape': 'Polygon', 'STATEFP': ...
#
#                                             geometry
# 0  {'rings': [[[-8608078.87744889, 4310879.947869...
# 1  {'rings': [[[-8429869.786865463, 4291798.18384...
# 2  {'rings': [[[-8761804.792557526, 4234648.80601...
# 3  {'rings': [[[-9160749.25508372, 4257980.584786...
# 4  {'rings': [[[-8616429.51120074, 4301301.153104...

# %%
#Explode the dictionary values into fields
dfCounties = df['attributes'].apply(pd.Series)
dfGeom = df['geometry'].apply(pd.Series)

# %%
#Combine the two
dfAll = pd.concat((dfCounties,dfGeom),axis='rows')
dfAll.columns
# Out:
# Index(['AFFGEOID', 'ALAND', 'AWATER', 'COUNTYFP', 'COUNTYNS', 'FID', 'GEOID',
#        'LSAD', 'NAME', 'STATEFP', 'Shape', 'rings', 'spatialReference'],
#       dtype='object')

# %% [markdown]
# ### Converting the geometry coordinates to a geometric feature
# * Exploring the 'rings' object
# * Exploring the `shapely` package
# * Using shapely to create features
# * Converting the dataFrame to geodataFrame
# * Plotting the output

# %%
#Demo creating a shapely polygnon from the JSON ring
rings = dfAll['rings'][0]
print ("There is/are {} ring(s)".format(len(rings)))
print ("There are {} vertices in the first ring".format(len(rings[0])))
print ("The first vertex is at {}".format(rings[0][0]))
# Out:
# There is/are 2 ring(s)
# There are 2 vertices in the first ring
# The first vertex is at 0                                                  NaN
# 0    [[[-8608078.87744889, 4310879.947869732], [-86...
# Name: rings, dtype: object

# %%
from shapely.geometry import LinearRing
from shapely.geometry import Polygon
ring = rings[0]
r = LinearRing(ring)
s = Polygon(r)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\shapely\speedups\_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#
# AttributeError: 'Series' object has no attribute '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-5b699c23ba3d> in <module>()
#       2 from shapely.geometry import Polygon
#       3 ring = rings[0]
# ----> 4 r = LinearRing(ring)
#       5 s = Polygon(r)
#
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\shapely\geometry\polygon.py in __init__(self, coordinates)
#      51         BaseGeometry.__init__(self)
#      52         if coordinates is not None:
# ---> 53             self._set_coords(coordinates)
#      54
#      55     @property
#
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\shapely\geometry\polygon.py in _set_coords(self, coordinates)
#      66     def _set_coords(self, coordinates):
#      67         self.empty()
# ---> 68         ret = geos_linearring_from_py(coordinates)
#      69         if ret is not None:
#      70             self._geom, self._ndim = ret
#
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\shapely\speedups\_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# ValueError: A LinearRing must have at least 3 coordinate tuples

# %%
#https://shapely.readthedocs.io/en/latest/manual.html#polygons
from shapely.geometry import Polygon
from shapely.geometry import LinearRing
def polyFromRing(ring):
    r = LinearRing(ring)
    s = Polygon(r)
    return r
dfAll['geometry']=dfAll.apply(lambda x: Polygon(x.rings[0]),axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-cd0b1e12a01f> in <module>()
#       6     s = Polygon(r)
#       7     return r
# ----> 8 dfAll['geometry']=dfAll.apply(lambda x: Polygon(x.rings[0]),axis=1)
#
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# ~\AppData\Local\ESRI\conda\envs\my_env\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
#    4975             except Exception as e:
#
# <ipython-input-15-cd0b1e12a01f> in <lambda>(x)
#       6     s = Polygon(r)
#       7     return r
# ----> 8 dfAll['geometry']=dfAll.apply(lambda x: Polygon(x.rings[0]),axis=1)
#
# TypeError: ("'float' object is not subscriptable", 'occurred at index 0')

# %%
gdf=gpd.GeoDataFrame(dfAll)

# %%
gdf[gdf['NAME'] == 'Durham'].plot();

# %%
gdf.to_csv("counties_{}.csv".format(stateFIPS))
